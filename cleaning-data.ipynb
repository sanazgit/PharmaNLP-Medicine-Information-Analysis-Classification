# %% [markdown]
# # **Overview of the Dataset and Cleaning Steps**
#
#
# **The Medicines Information Dataset (MID)** is one of the largest publicly available textual datasets on medicines, containing over 192,000 medicine records across 44 therapeutic classes. Each record provides detailed information such as drug names, therapeutic uses, side effects, benefits, dosage instructions, mechanisms of action, safety advice, chemical and therapeutic classes, and more.
#
# This dataset serves as a valuable resource for medical researchers, healthcare professionals, drug manufacturers, and data scientists working on drug information retrieval, classification, prediction, and natural language processing (NLP) applications.
#
# **Challenges in the Raw Data**
#
#
# While MID is rich in content, the raw data contains several issues that required careful cleaning:
#
#
# * HTML tags and other text noise embedded within fields.Duplicate records across
# * multiple entries.Inconsistent categorical values, such as extra or misplaced characters in class labels.
# * String-based NaN values that needed conversion to proper null types.
#
#
# **Data Cleaning Summary**
#
# To prepare the dataset for analysis and modeling, the following preprocessing steps were performed:
#
#
# 1. Removal of HTML tags and formatting noise using robust parsing and regex cleaning.
# 2. Elimination of duplicate rows.
# 3. Standardization of categorical fields by stripping unnecessary words or characters.
# 4. Conversion of string "nan" and similar placeholders into proper missing values.
# 5. Targeted corrections for stray characters or substrings within specific columns.
#
#
# These cleaning operations have transformed the dataset into a consistent, noise-free, and analysis-ready format, suitable for further exploratory analysis, visualization, and machine learning workflows.

# %% [markdown]
# ## Install Required Libraries
#
# We install **beautifulsoup4** and **lxml** to enable HTML parsing and web scraping capabilities in later steps

# %%
# !pip install beautifulsoup4 lxml

# %%
import numpy as np 
import pandas as pd 
import os

import seaborn as sns
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
import html, re, pathlib

# %% [markdown]
# ## Load Dataset

# %%
data= pd.read_excel('/kaggle/input/medical-information-dataset/MID.xlsx')
data.head(5)
# Out:
#                       Name                                               Link  \
# 0       Andol 0.5mg Tablet  https://www.1mg.com/drugs/andol-0.5mg-tablet-6...
# 1  Avastin 100mg Injection  https://www.1mg.com/drugs/avastin-100mg-inject...
# 2    Actorise 40 Injection  https://www.1mg.com/drugs/actorise-40-injectio...
# 3    Actorise 25 Injection  https://www.1mg.com/drugs/actorise-25-injectio...
# 4    Actorise 60 Injection  https://www.1mg.com/drugs/actorise-60-injectio...
#
#                    Contains  \
# 0       Haloperidol (0.5mg)
# 1       Bevacizumab (100mg)
# 2  Darbepoetin alfa (40mcg)
# 3  Darbepoetin alfa (25mcg)
# 4  Darbepoetin alfa (60mcg)
#
#                                  ProductIntroduction  \
# 0  Andol 0.5mg Tablet can also be used for treati...
# 1  \np dir=\"ltr\" style=\"line-height: 1.38; mar...
# 2  Actorise 40 Injection is a medicine that needs...
# 3  Actorise 25 Injection is a medicine that needs...
# 4  Actorise 60 Injection is a medicine that needs...
#
#                                          ProductUses  \
# 0  \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Schiz...
# 1  \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Cance...
# 2  \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Treat...
# 3  \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Treat...
# 4  \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Treat...
#
#                                      ProductBenefits  \
# 0   \n  \n Schizophrenia \n  \n Schizophrenia is ...
# 1   \n  \n Cancer of colon and rectum \n  \n Canc...
# 2   \n  \n Treatment of Anemia due to chronic kid...
# 3   \n  \n Treatment of Anemia due to chronic kid...
# 4   \n  \n Treatment of Anemia due to chronic kid...
#
#                                           SideEffect  \
# 0  Most side effects do not require any medical a...
# 1  Most side effects do not require any medical a...
# 2  Most side effects do not require any medical a...
# 3  Most side effects do not require any medical a...
# 4  Most side effects do not require any medical a...
#
#                                             HowToUse  \
# 0  Take this medicine in the dose and duration as...
# 1  Your doctor or nurse will give you this medici...
# 2  Your doctor or nurse will give you this medici...
# 3  Your doctor or nurse will give you this medici...
# 4  Your doctor or nurse will give you this medici...
#
#                                             HowWorks  \
# 0  Andol 0.5mg Tablet is a typical antipsychotic....
# 1  Avastin 100mg Injection is a anti-angiogenic m...
# 2  Actorise 40 Injection is an erythropoiesis-sti...
# 3  Actorise 25 Injection is an erythropoiesis-sti...
# 4  Actorise 60 Injection is an erythropoiesis-sti...
#
#                                            QuickTips  \
# 0   \n  \n Andol 0.5mg Tablet helps treat schizop...
# 1   \n  \n Avastin 100mg Injection is an effectiv...
# 2   \n  \n Actorise 40 Injection helps in the tre...
# 3   \n  \n Actorise 25 Injection helps in the tre...
# 4   \n  \n Actorise 60 Injection helps in the tre...
#
#                                         SafetyAdvice  \
# 0  \nAlcohol\n,\nAndol 0.5mg Tablet may cause exc...
# 1  \nAlcohol\n,\nIt is not known whether it is sa...
# 2  \nAlcohol\n,\nIt is not known whether it is sa...
# 3  \nAlcohol\n,\nIt is not known whether it is sa...
# 4  \nAlcohol\n,\nIt is not known whether it is sa...
#
#                        Chemical_Class Habit_Forming    Therapeutic_Class  \
# 0           Butyrophenone Derivative            No            NEURO CNS
# 1          Monoclonal antibody (mAb)            No     ANTI NEOPLASTICS
# 2    Amino Acids, Peptides Analogues            No        BLOOD RELATED
# 3    Amino Acids, Peptides Analogues            No        BLOOD RELATED
# 4    Amino Acids, Peptides Analogues            No        BLOOD RELATED
#
#                                         Action_Class
# 0                              Typical Antipsychotic
# 1    Vascular endothelial growth factor (VEGF) in...
# 2              Erythropoiesis-stimulating agent (ESA
# 3              Erythropoiesis-stimulating agent (ESA
# 4              Erythropoiesis-stimulating agent (ESA

# %%
print(f"Dataset shape: {data.shape[0]} rows, {data.shape[1]} columns\n")
# Out:
# Dataset shape: 192807 rows, 15 columns

# %%
# Display basic information
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192807 entries, 0 to 192806
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Name                 192807 non-null  object
#  1   Link                 192807 non-null  object
#  2   Contains             192807 non-null  object
#  3   ProductIntroduction  180821 non-null  object
#  4   ProductUses          192807 non-null  object
#  5   ProductBenefits      192807 non-null  object
#  6   SideEffect           192807 non-null  object
#  7   HowToUse             192712 non-null  object
#  8   HowWorks             192571 non-null  object
#  9   QuickTips            192807 non-null  object
#  10  SafetyAdvice         192807 non-null  object
#  11  Chemical_Class       101473 non-null  object
#  12  Habit_Forming        192807 non-null  object
#  13  Therapeutic_Class    192807 non-null  object
#  14  Action_Class         85690 non-null   object
# dtypes: object(15)
# memory usage: 22.1+ MB
# None

# %%
# Display summary statistics
data.describe()
# Out:
#                     Name                                               Link  \
# count             192807                                             192807
# unique            147872                                             151007
# top     NS 0.9% Infusion  https://www.1mg.com/drugs/oltrypsin-forte-1000...
# freq                  12                                                  5
#
#                    Contains  \
# count                192807
# unique                11940
# top     Pantoprazole (40mg)
# freq                   2205
#
#                                       ProductIntroduction  \
# count                                              180821
# unique                                             136893
# top     Give this medicine to your child an hour befor...
# freq                                                  506
#
#                                               ProductUses ProductBenefits  \
# count                                              192807          192807
# unique                                               1147          144479
# top     \n  \n  \nul \"\"\n\n   \n 0\n\n    \n   Treat...     efits":null
# freq                                                19283            2994
#
#        SideEffect                                           HowToUse  \
# count      192807                                             192712
# unique     121482                                             120713
# top        ":null  Your doctor or nurse will give you this medici...
# freq         3558                                              17018
#
#                                                  HowWorks QuickTips  \
# count                                              192571    192807
# unique                                             145994    137470
# top     Montelukast is a leukotriene antagonist. It wo...     :null
# freq                                                  676      1463
#
#        SafetyAdvice      Chemical_Class Habit_Forming   Therapeutic_Class  \
# count        192807              101473        192807              192807
# unique       147857                 869             4                  44
# top              \n    Fluoroquinolone            No     ANTI INFECTIVES
# freq            229                4805        188428               20291
#
#                           Action_Class
# count                            85690
# unique                             405
# top       Cephalosporins   3 generatio
# freq                              5888

# %% [markdown]
# ## Visualize distributions

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data['Therapeutic_Class'], kde=False) 

plt.xticks(rotation=90)  
plt.xlabel("Therapeutic Class", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Distribution of Therapeutic Classes", fontsize=16)

plt.tight_layout() 
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
#  ## Clean HTML/Styling Noise from Text Columns

# %%
data_clean = data.copy()

# %%
from bs4 import MarkupResemblesLocatorWarning
import warnings

warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

ATTR_NAMES = r"(?:dir|style|class|id|lang|align|valign|width|height|color|face|size|border)"

ATTR_PAIR   = re.compile(rf"\b{ATTR_NAMES}\s*=\s*(?:\"[^\"]*\"|'[^']*'|[^\s\"'>]+)\b", re.I)

EMPTY_ATTR  = re.compile(rf"\b{ATTR_NAMES}\s*=\s*(?:\"[ \t]*\"|'[ \t]*')\b", re.I)

CSS_PAIR    = re.compile(r"\b[a-z-]+\s*:\s*[^;]+;?")
HEX_COLOR   = re.compile(r"#(?:[0-9a-fA-F]{3}|[0-9a-fA-F]{6})\b")

SLASH_TAG   = re.compile(r"(?<!<)/\s*(?:[a-z][a-z0-9]*)\b", re.I)
BARE_TAGS   = re.compile(r"\b(?:p|span|strong|em|b|i|u|br|div|ul|li|ol|h[1-6])\b", re.I)

BULLETS     = re.compile(r"(?m)^\s*(?:[\-\*\u2022]|\d{1,3}[.)])\s+")

LIT_ESC     = re.compile(r"\\[nrt]")

URL_LIKE    = re.compile(r"^https?://\S+$", re.I)

MULTISPACE  = re.compile(r"\s+")

EMPTY_TOKENS = {"", "na", "<na>", "n/a", "none", "null", "-", "—", "–"}

def clean_html_robust(text, *, to_lower=False, return_empty_as_na=True, max_passes=3):
    if pd.isna(text):
        return pd.NA

    raw = str(text)

    # 1) HTML entities
    raw = html.unescape(raw)

    # 2) unsupported escapes → escape
    raw = re.sub(r'\\(?![abfnrtv"\'\\0-7xXuU])', r'\\\\', raw)

    # 3) decode legitimate escapes
    raw = raw.encode("utf-8").decode("unicode_escape", errors="ignore")

    # 4) lowercase
    raw = raw.lower()

    if not URL_LIKE.match(raw):
        plain = BeautifulSoup(raw, "html.parser").get_text(" ", strip=True)
    else:
        plain = raw


    for _ in range(max_passes):
        old = plain
    
        plain = ATTR_PAIR.sub(" ", plain)
        plain = CSS_PAIR.sub(" ", plain)
        plain = HEX_COLOR.sub(" ", plain)
        plain = EMPTY_ATTR.sub(" ", plain)

        
        plain = SLASH_TAG.sub(" ", plain)
        plain = BARE_TAGS.sub(" ", plain)

        plain = BULLETS.sub("", plain)

        plain = LIT_ESC.sub(" ", plain)
        plain = plain.replace("\n", " ").replace("\r", " ").replace("\t", " ")

        plain = MULTISPACE.sub(" ", plain).strip()

        if plain == old:
            break

    if return_empty_as_na and plain.lower() in EMPTY_TOKENS:
        return pd.NA

    return plain

data_cols = [col for col in data_clean.columns 
             if col not in ['Link', 'Therapeutic_Class']]

for col in data_cols:
    data_clean[col] = data_clean[col].apply(clean_html_robust)

data_clean.head(5)
# Out:
#                       Name                                               Link  \
# 0       andol 0.5mg tablet  https://www.1mg.com/drugs/andol-0.5mg-tablet-6...
# 1  avastin 100mg injection  https://www.1mg.com/drugs/avastin-100mg-inject...
# 2    actorise 40 injection  https://www.1mg.com/drugs/actorise-40-injectio...
# 3    actorise 25 injection  https://www.1mg.com/drugs/actorise-25-injectio...
# 4    actorise 60 injection  https://www.1mg.com/drugs/actorise-60-injectio...
#
#                    Contains  \
# 0       haloperidol (0.5mg)
# 1       bevacizumab (100mg)
# 2  darbepoetin alfa (40mcg)
# 3  darbepoetin alfa (25mcg)
# 4  darbepoetin alfa (60mcg)
#
#                                  ProductIntroduction  \
# 0  andol 0.5mg tablet can also be used for treati...
# 1  dir="ltr" style=" " style=" " avastin 100mg in...
# 2  actorise 40 injection is a medicine that needs...
# 3  actorise 25 injection is a medicine that needs...
# 4  actorise 60 injection is a medicine that needs...
#
#                                          ProductUses  \
# 0                                 "" 0 schizophrenia
# 1  "" 0 cancer of colon and rectum 1 non-small ce...
# 2  "" 0 treatment of anemia due to chronic kidney...
# 3  "" 0 treatment of anemia due to chronic kidney...
# 4  "" 0 treatment of anemia due to chronic kidney...
#
#                                      ProductBenefits  \
# 0  schizophrenia schizophrenia is a mental disord...
# 1  cancer of colon and rectum cancer of the colon...
# 2  treatment of anemia due to chronic kidney dise...
# 3  treatment of anemia due to chronic kidney dise...
# 4  treatment of anemia due to chronic kidney dise...
#
#                                           SideEffect  \
# 0  most side effects do not require any medical a...
# 1  most side effects do not require any medical a...
# 2  most side effects do not require any medical a...
# 3  most side effects do not require any medical a...
# 4  most side effects do not require any medical a...
#
#                                             HowToUse  \
# 0  take this medicine in the dose and duration as...
# 1  your doctor or nurse will give you this medici...
# 2  your doctor or nurse will give you this medici...
# 3  your doctor or nurse will give you this medici...
# 4  your doctor or nurse will give you this medici...
#
#                                             HowWorks  \
# 0  andol 0.5mg tablet is a typical antipsychotic....
# 1  avastin 100mg injection is a anti-angiogenic m...
# 2  actorise 40 injection is an erythropoiesis-sti...
# 3  actorise 25 injection is an erythropoiesis-sti...
# 4  actorise 60 injection is an erythropoiesis-sti...
#
#                                            QuickTips  \
# 0  andol 0.5mg tablet helps treat schizophrenia. ...
# 1  avastin 100mg injection is an effective, first...
# 2  actorise 40 injection helps in the treatment o...
# 3  actorise 25 injection helps in the treatment o...
# 4  actorise 60 injection helps in the treatment o...
#
#                                         SafetyAdvice  \
# 0  alcohol , andol 0.5mg tablet may cause excessi...
# 1  alcohol , it is not known whether it is safe t...
# 2  alcohol , it is not known whether it is safe t...
# 3  alcohol , it is not known whether it is safe t...
# 4  alcohol , it is not known whether it is safe t...
#
#                     Chemical_Class Habit_Forming    Therapeutic_Class  \
# 0         butyrophenone derivative            no           NEURO CNS
# 1        monoclonal antibody (mab)            no    ANTI NEOPLASTICS
# 2  amino acids, peptides analogues            no       BLOOD RELATED
# 3  amino acids, peptides analogues            no       BLOOD RELATED
# 4  amino acids, peptides analogues            no       BLOOD RELATED
#
#                                         Action_Class
# 0                              typical antipsychotic
# 1  vascular endothelial growth factor (vegf) inhi...
# 2              erythropoiesis-stimulating agent (esa
# 3              erythropoiesis-stimulating agent (esa
# 4              erythropoiesis-stimulating agent (esa

# %% [markdown]
# ### ***Other Removing Noise :)***

# %%
data_clean['ProductUses'] = (
    data_clean['ProductUses']
        .str.replace(r'^\s*"+\s*', '', regex=True)
        .str.replace(r'\s*"+\s*$', '', regex=True)
        .str.strip()
)

# %%
data_clean["Habit_Forming"] = data_clean["Habit_Forming"].str.replace("~", "", regex=False)
data_clean["ProductBenefits"] = data_clean["ProductBenefits"].str.replace('efits":null', '', regex=False)
data_clean["QuickTips"] = data_clean["QuickTips"].str.replace(":null", "", regex=False)
data_clean["ProductUses"] = data_clean["ProductUses"].str.replace(r"^0\s*", "", regex=True)

# %%
data_clean["ProductBenefits"][207:214]
# Out:
# 207
# 208    medical abortion a kare combipack is used to c...
# 209    treatment of cough with mucus alkof syrup help...
# 210    prevention of rabies rabies is a serious disea...
# 211    treatment of bacterial infections azikem 500mg...
# 212    prevention of angina (heart-related chest pain...
# 213    dry cough a dry cough is a cough where no phle...
# Name: ProductBenefits, dtype: object

# %% [markdown]
# ### ***Edite Target Column***

# %%
data['Therapeutic_Class'].unique()
# Out:
# array(['  NEURO CNS ', '  ANTI NEOPLASTICS ', '  BLOOD RELATED ',
#        '  ANTI NEOPLASTIC', '  ANTI INFECTIVE', '  RESPIRATOR',
#        '  ANTI INFECTIVES ', '  RESPIRATORY ', '  GASTRO INTESTINAL ',
#        '  CARDIAC ', '  DERM', '  UROLOGY ', '  CARDIA',
#        '  PAIN ANALGESIC', '  NEURO CN', '  GASTRO INTESTINA',
#        '  VITAMINS MINERALS NUTRIENTS ', '  GYNAECOLOGICA', '  DERMA ',
#        '  VITAMINS MINERALS NUTRIENT', '  VACCINE', '  ANTI DIABETIC ',
#        '  SEX STIMULANTS REJUVENATOR', '  ANTI DIABETI', '  VACCINES ',
#        '  OPHTHA', '  SEX STIMULANTS REJUVENATORS ', '  UROLOG',
#        '  BLOOD RELATE', '  OPHTHAL ', '  OPHTHAL OTOLOGICAL',
#        '  PAIN ANALGESICS ', '  GYNAECOLOGICAL ', '  STOMATOLOGICAL',
#        '  OTOLOGICAL', '  HORMONES ', '  OTHERS ', '  HORMONE',
#        '  OPHTHAL OTOLOGICALS ', '  ANTI MALARIAL', '  ANTI MALARIALS ',
#        '  OTHER', '  OTOLOGICALS ', '  STOMATOLOGICALS '], dtype=object)

# %%
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*ANTI NEOPLASTIC\s*$', 'ANTI NEOPLASTICS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*ANTI INFECTIVE\s*$', 'ANTI INFECTIVES', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*RESPIRATOR\s*$', 'RESPIRATORY', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*GASTRO INTESTINA\s*$', 'GASTRO INTESTINAL', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*CARDIA\s*$', 'CARDIAC', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*DERM\s*$', 'DERMA', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*BLOOD RELATE\s*$', 'BLOOD RELATED', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*NEURO CN\s*$', 'NEURO CNS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*UROLOG\s*$', 'UROLOGY', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*PAIN ANALGESIC\s*$', 'PAIN ANALGESICS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*VITAMINS MINERALS NUTRIENT\s*$', 'VITAMINS MINERALS NUTRIENTS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*GYNAECOLOGICA\s*$', 'GYNAECOLOGICAL', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*VACCINE\s*$', 'VACCINES', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*ANTI DIABETI\s*$', 'ANTI DIABETIC', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*SEX STIMULANTS REJUVENATOR\s*$', 'SEX STIMULANTS REJUVENATORS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*OPHTHA\s*$', 'OPHTHAL', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*OPHTHAL OTOLOGICAL\s*$', 'OPHTHAL OTOLOGICALS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*STOMATOLOGICAL\s*$', 'STOMATOLOGICALS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*OTOLOGICAL\s*$', 'OTOLOGICALS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*HORMONE\s*$', 'HORMONES', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*ANTI MALARIAL\s*$', 'ANTI MALARIALS', regex=True)
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'] .replace(r'^\s*OTHER\s*$', 'OTHERS', regex=True)


data_clean['Therapeutic_Class']  = data_clean['Therapeutic_Class'] .str.strip()
data_clean['Therapeutic_Class'] = data_clean['Therapeutic_Class'].str.lower()

# %%
data_clean['Therapeutic_Class'].unique()
# Out:
# array(['neuro cns', 'anti neoplastics', 'blood related',
#        'anti infectives', 'respiratory', 'gastro intestinal', 'cardiac',
#        'derma', 'urology', 'pain analgesics',
#        'vitamins minerals nutrients', 'gynaecological', 'vaccines',
#        'anti diabetic', 'sex stimulants rejuvenators', 'ophthal',
#        'ophthal otologicals', 'stomatologicals', 'otologicals',
#        'hormones', 'others', 'anti malarials'], dtype=object)

# %% [markdown]
# ## Remove Duplicates

# %%
duplicates = data_clean[data_clean.duplicated(keep=False)]
duplicates
# Out:
#                            Name  \
# 0            andol 0.5mg tablet
# 1       avastin 100mg injection
# 2         actorise 40 injection
# 3         actorise 25 injection
# 4         actorise 60 injection
# ...                         ...
# 192690      zensita 50mg tablet
# 192691    zyfor 300mg tablet er
# 192693        zepnap 2mg tablet
# 192776      zaride 0.5mg tablet
# 192777      zaride 0.5mg tablet
#
#                                                      Link  \
# 0       https://www.1mg.com/drugs/andol-0.5mg-tablet-6...
# 1       https://www.1mg.com/drugs/avastin-100mg-inject...
# 2       https://www.1mg.com/drugs/actorise-40-injectio...
# 3       https://www.1mg.com/drugs/actorise-25-injectio...
# 4       https://www.1mg.com/drugs/actorise-60-injectio...
# ...                                                   ...
# 192690  https://www.1mg.com/drugs/zensita-50mg-tablet-...
# 192691  https://www.1mg.com/drugs/zyfor-300mg-tablet-e...
# 192693  https://www.1mg.com/drugs/zepnap-2mg-tablet-23...
# 192776  https://www.1mg.com/drugs/zaride-0.5mg-tablet-...
# 192777  https://www.1mg.com/drugs/zaride-0.5mg-tablet-...
#
#                         Contains  \
# 0            haloperidol (0.5mg)
# 1            bevacizumab (100mg)
# 2       darbepoetin alfa (40mcg)
# 3       darbepoetin alfa (25mcg)
# 4       darbepoetin alfa (60mcg)
# ...                          ...
# 192690        sitagliptin (50mg)
# 192691         faropenem (300mg)
# 192693           lorazepam (2mg)
# 192776       dutasteride (0.5mg)
# 192777       dutasteride (0.5mg)
#
#                                       ProductIntroduction  \
# 0       andol 0.5mg tablet can also be used for treati...
# 1       dir="ltr" style=" " style=" " avastin 100mg in...
# 2       actorise 40 injection is a medicine that needs...
# 3       actorise 25 injection is a medicine that needs...
# 4       actorise 60 injection is a medicine that needs...
# ...                                                   ...
# 192690  zensita 50mg tablet is normally prescribed whe...
# 192691  zyfor 300mg tablet er is the only medicine of ...
# 192693  zepnap 2mg tablet is taken by mouth with or wi...
# 192776  zaride 0.5mg tablet can be taken with or witho...
# 192777  zaride 0.5mg tablet can be taken with or witho...
#
#                                               ProductUses  \
# 0                                           schizophrenia
# 1       cancer of colon and rectum 1 non-small cell lu...
# 2       treatment of anemia due to chronic kidney dise...
# 3       treatment of anemia due to chronic kidney dise...
# 4       treatment of anemia due to chronic kidney dise...
# ...                                                   ...
# 192690              treatment of type 2 diabetes mellitus
# 192691           treatment of severe bacterial infections
# 192693  treatment of short term anxiety 1 treatment of...
# 192776                       benign prostatic hyperplasia
# 192777                       benign prostatic hyperplasia
#
#                                           ProductBenefits  \
# 0       schizophrenia schizophrenia is a mental disord...
# 1       cancer of colon and rectum cancer of the colon...
# 2       treatment of anemia due to chronic kidney dise...
# 3       treatment of anemia due to chronic kidney dise...
# 4       treatment of anemia due to chronic kidney dise...
# ...                                                   ...
# 192690  treatment of type 2 diabetes mellitus zensita ...
# 192691  treatment of severe bacterial infections zyfor...
# 192693  treatment of short term anxiety zepnap 2mg tab...
# 192776  benign prostatic hyperplasia when your prostat...
# 192777  benign prostatic hyperplasia when your prostat...
#
#                                                SideEffect  \
# 0       most side effects do not require any medical a...
# 1       most side effects do not require any medical a...
# 2       most side effects do not require any medical a...
# 3       most side effects do not require any medical a...
# 4       most side effects do not require any medical a...
# ...                                                   ...
# 192690  most side effects do not require any medical a...
# 192691  most side effects do not require any medical a...
# 192693  most side effects do not require any medical a...
# 192776  most side effects do not require any medical a...
# 192777  most side effects do not require any medical a...
#
#                                                  HowToUse  \
# 0       take this medicine in the dose and duration as...
# 1       your doctor or nurse will give you this medici...
# 2       your doctor or nurse will give you this medici...
# 3       your doctor or nurse will give you this medici...
# 4       your doctor or nurse will give you this medici...
# ...                                                   ...
# 192690  take this medicine in the dose and duration as...
# 192691  take this medicine in the dose and duration as...
# 192693  take this medicine in the dose and duration as...
# 192776  take this medicine in the dose and duration as...
# 192777  take this medicine in the dose and duration as...
#
#                                                  HowWorks  \
# 0       andol 0.5mg tablet is a typical antipsychotic....
# 1       avastin 100mg injection is a anti-angiogenic m...
# 2       actorise 40 injection is an erythropoiesis-sti...
# 3       actorise 25 injection is an erythropoiesis-sti...
# 4       actorise 60 injection is an erythropoiesis-sti...
# ...                                                   ...
# 192690  zensita 50mg tablet is an antidiabetic medicat...
# 192691  zyfor 300mg tablet er is an antibiotic. it kil...
# 192693  zepnap 2mg tablet is a benzodiazepine. it work...
# 192776  zaride 0.5mg tablet is a 5-alpha reductase inh...
# 192777  zaride 0.5mg tablet is a 5-alpha reductase inh...
#
#                                                 QuickTips  \
# 0       andol 0.5mg tablet helps treat schizophrenia. ...
# 1       avastin 100mg injection is an effective, first...
# 2       actorise 40 injection helps in the treatment o...
# 3       actorise 25 injection helps in the treatment o...
# 4       actorise 60 injection helps in the treatment o...
# ...                                                   ...
# 192690  zensita 50mg tablet should be taken at the sam...
# 192691  zyfor 300mg tablet er helps treat severe bacte...
# 192693  the addiction -forming potential of this medic...
# 192776  your doctor has prescribed zaride 0.5mg tablet...
# 192777  your doctor has prescribed zaride 0.5mg tablet...
#
#                                              SafetyAdvice  \
# 0       alcohol , andol 0.5mg tablet may cause excessi...
# 1       alcohol , it is not known whether it is safe t...
# 2       alcohol , it is not known whether it is safe t...
# 3       alcohol , it is not known whether it is safe t...
# 4       alcohol , it is not known whether it is safe t...
# ...                                                   ...
# 192690  alcohol , it is unsafe to consume alcohol with...
# 192691  alcohol , it is not known whether it is safe t...
# 192693  alcohol , it is unsafe to consume alcohol with...
# 192776  alcohol , it is not known whether it is safe t...
# 192777  alcohol , it is not known whether it is safe t...
#
#                          Chemical_Class Habit_Forming Therapeutic_Class  \
# 0              butyrophenone derivative            no         neuro cns
# 1             monoclonal antibody (mab)            no  anti neoplastics
# 2       amino acids, peptides analogues            no     blood related
# 3       amino acids, peptides analogues            no     blood related
# 4       amino acids, peptides analogues            no     blood related
# ...                                 ...           ...               ...
# 192690              pyrazine-derivative            no     anti diabetic
# 192691    alpha amino acids derivatives            no   anti infectives
# 192693       benzodiazepines derivative           yes         neuro cns
# 192776              androgen derivative            no           urology
# 192777              androgen derivative            no           urology
#
#                                              Action_Class
# 0                                   typical antipsychotic
# 1       vascular endothelial growth factor (vegf) inhi...
# 2                   erythropoiesis-stimulating agent (esa
# 3                   erythropoiesis-stimulating agent (esa
# 4                   erythropoiesis-stimulating agent (esa
# ...                                                   ...
# 192690                                    dpp-4 inhibitor
# 192691                                               <NA>
# 192693                                     benzodiazepine
# 192776                 5 alpha- reductase inhibitor (5ari
# 192777                 5 alpha- reductase inhibitor (5ari
#
# [78335 rows x 15 columns]

# %% [markdown]
# Now, check duplicates 🤔

# %%
first_row = data_clean.iloc[1]

matching_first_row = data_clean[data_clean.eq(first_row).all(axis=1)]

matching_first_row
# Out:
#                        Name  \
# 1   avastin 100mg injection
# 31  avastin 100mg injection
#
#                                                  Link             Contains  \
# 1   https://www.1mg.com/drugs/avastin-100mg-inject...  bevacizumab (100mg)
# 31  https://www.1mg.com/drugs/avastin-100mg-inject...  bevacizumab (100mg)
#
#                                   ProductIntroduction  \
# 1   dir="ltr" style=" " style=" " avastin 100mg in...
# 31  dir="ltr" style=" " style=" " avastin 100mg in...
#
#                                           ProductUses  \
# 1   cancer of colon and rectum 1 non-small cell lu...
# 31  cancer of colon and rectum 1 non-small cell lu...
#
#                                       ProductBenefits  \
# 1   cancer of colon and rectum cancer of the colon...
# 31  cancer of colon and rectum cancer of the colon...
#
#                                            SideEffect  \
# 1   most side effects do not require any medical a...
# 31  most side effects do not require any medical a...
#
#                                              HowToUse  \
# 1   your doctor or nurse will give you this medici...
# 31  your doctor or nurse will give you this medici...
#
#                                              HowWorks  \
# 1   avastin 100mg injection is a anti-angiogenic m...
# 31  avastin 100mg injection is a anti-angiogenic m...
#
#                                             QuickTips  \
# 1   avastin 100mg injection is an effective, first...
# 31  avastin 100mg injection is an effective, first...
#
#                                          SafetyAdvice  \
# 1   alcohol , it is not known whether it is safe t...
# 31  alcohol , it is not known whether it is safe t...
#
#                Chemical_Class Habit_Forming Therapeutic_Class  \
# 1   monoclonal antibody (mab)            no  anti neoplastics
# 31  monoclonal antibody (mab)            no  anti neoplastics
#
#                                          Action_Class
# 1   vascular endothelial growth factor (vegf) inhi...
# 31  vascular endothelial growth factor (vegf) inhi...

# %%
data_clean = data_clean.drop_duplicates()

# %%
plt.figure(figsize=(18, 6))
sns.histplot(data_clean['Therapeutic_Class'], kde=False) 

plt.xticks(rotation=90)  
plt.xlabel("Therapeutic Class", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Distribution of Therapeutic Classes", fontsize=16)

plt.tight_layout() 
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## ✔ Save Clean Dataset

# %%
clean_data = data_clean
clean_data.to_excel('Medical_clean.xlsx', index=False)
